# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/NLP_project2/sent-bias-master/sentbias/encoders
# Out:
# bert.py

# %%
# !pip install pytorch_pretrained_bert
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd /content/drive/MyDrive/NLP_project2/sent-bias-master/
# Out:
# /content/drive/MyDrive/NLP_project2/sent-bias-master

# %%
# !python sentbias/main.py -t angry_black_woman_stereotype_b --results_path "../sent-bias-master/results1.txt"
# Out:
# 11/24 08:00:37 PM: NumExpr defaulting to 2 threads.
# 11/24 08:00:39 PM: Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# 11/24 08:00:39 PM: Seeding random number generators with 1111
# 11/24 08:00:39 PM: Parsed args:
# Namespace(bert_version='bert-large-cased', data_dir='tests', dont_cache_encs=False, ignore_cached_encs=False, log_file=None, model='bert', n_samples=100000, parametric=False, results_path='../sent-bias-master/results1.txt', seed=1111, tests='angry_black_woman_stereotype_b')
# 11/24 08:00:39 PM: Tests selected:
# 11/24 08:00:39 PM: 	angry_black_woman_stereotype_b
# 11/24 08:00:39 PM: 	bert
# 11/24 08:00:39 PM: Running tests for model bert
# 11/24 08:00:39 PM: Loading tests/angry_black_woman_stereotype_b.jsonl...
# 11/24 08:00:39 PM: Running test angry_black_woman_stereotype_b for model bert
# 11/24 08:00:39 PM: Computing sentence encodings
# ...
